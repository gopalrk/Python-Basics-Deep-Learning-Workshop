# %% [markdown]
# # Exploring Numpy, Pandas, and Matplotlib

# %% [markdown]
# ## <font color='red'> Numpy

# %%
# Why Numpy is required?

a= [1,2,3,4]
b= [1,2,3,4]

c=a*b
print(c)

# %%
import numpy as np

a=np.array(a)
b=np.array(b)
c=a*b
print(c)

# %%
# Also numpy is required to create n-dimentional matrix

a=[[1,2,3,4],[5,6,7,8]]
print(a)

# %%
np.array(a)

# %%
a=[[1,2,3,4],[5,6,7,8]]
b=[[1,2,3,4],[5,6,7,8]]

a=np.array(a)
b=np.array(b)

# %%
c=a*b

# %%
print(c)

# %%
print(c[1][1])
print(c[0][0])

# %% [markdown]
# ## <font color='red'> Pandas

# %% [markdown]
# Pandas library provides **Series** and **DataFrames** type of data structure which are extensively used while dealing with data files

# %%
# Series
import pandas as pd

a =np.array([1,2,3])
rowname=['first','second','third']
myseries=pd.Series(a,index=rowname)

# %%
myseries['first']

# %%
# DataFrame

a= np.array([[1,2,3],[4,5,6]])
rowname=['first','second']
colname=['firstCol','secondCol','thirdCol']

# %%
DtFrm=pd.DataFrame(a,index=rowname,columns=colname)

# %%
print(DtFrm)

# %% [markdown]
# ###  <font color='red'> Pandas Accessing datafiles using Pandas

# %%
url= "https://www.ebi.ac.uk/fg/sym"
url2= "https://www.ebi.ac.uk/fg/sym/search/pheno/9__C1_SyM_1;ex;true;p"

PIMA_INDIAN_DIABETES_DATA="https://www.kaggle.com/uciml/pima-indians-diabetes-database/downloads/diabetes.csv/1"

data=pd.read_html(url2)

data=data[0]

# %%
data

# %%
PIMA_INDIAN_DIABETES_DATA_filename="pima-indians-diabetes_kaggle.csv"
names = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class']
data=pd.read_csv(PIMA_INDIAN_DIABETES_DATA_filename,names=names)

# %%
print(data.shape)

# %%
data.head(5)

# %%
data.tail(5)

# %%
print(data.dtypes)

# %% [markdown]
# ## <font color='red'> MatplotLib

# %% [markdown]
# **This is library is used for plotting figures and graphs in python**

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt
import numpy as np
 

x_value=np.array([1,2,3])
y_value=np.array([1,2,3])

plt.scatter(x_value,y_value)
plt.xlabel("Xlabel")
plt.ylabel("Ylabel")
plt.show()

# %%
# Example from https://matplotlib.org/gallery/shapes_and_collections/scatter.html#sphx-glr-gallery-shapes-and-collections-scatter-py

# %matplotlib inline 
import numpy as np
import matplotlib.pyplot as plt

# Fixing random state for reproducibility
np.random.seed(19680801)


N = 50
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = (30 * np.random.rand(N))**2  # 0 to 15 point radii

plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.show()
